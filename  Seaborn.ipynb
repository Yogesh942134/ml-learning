# %% [markdown]
# # 1. Relational Plot
# to see the statistical relation between 2 or more variables.
# Bivariate Analysis
# Plots under this section
#
# scatterplot
# lineplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np

# %% [markdown]
# **scatter plot**

# %%
tips = sns.load_dataset('tips')

# %%
# scatter plot -> axes level function #syntax
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='sex',style='time',size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# relplot -> figure level -> square shape
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',hue='sex',style='time',size='size')
# hue and syle work on same principle like c in matplot 
# size aslo same work as s  in matplot

# %%
# line plot 
gap = px.data.gapminder() # it is just a data set
temp = gap[gap["country"] == "India"]
temp
# Out:
#     country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696   India      Asia  1952   37.373   372000000   546.565749       IND
# 697   India      Asia  1957   40.249   409000000   590.061996       IND
# 698   India      Asia  1962   43.605   454000000   658.347151       IND
# 699   India      Asia  1967   47.193   506000000   700.770611       IND
# 700   India      Asia  1972   50.651   567000000   724.032527       IND
# 701   India      Asia  1977   54.208   634000000   813.337323       IND
# 702   India      Asia  1982   56.596   708000000   855.723538       IND
# 703   India      Asia  1987   58.553   788000000   976.512676       IND
# 704   India      Asia  1992   60.223   872000000  1164.406809       IND
# 705   India      Asia  1997   61.765   959000000  1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547  1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 696      356
# 697      356
# 698      356
# 699      356
# 700      356
# 701      356
# 702      356
# 703      356
# 704      356
# 705      356
# 706      356
# 707      356

# %%
# axes -> level plot
sns.lineplot(data=temp,x='year',y='lifeExp')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
# fig level -> plot
sns.relplot(data=temp,x='year',y='lifeExp',kind='line')

# %%
temp_df = gap[gap['country'].isin(['India','Brazil','Germany'])]
temp_df
# Out:
#      country continent  year  lifeExp         pop     gdpPercap iso_alpha  \
# 168   Brazil  Americas  1952   50.917    56602560   2108.944355       BRA
# 169   Brazil  Americas  1957   53.285    65551171   2487.365989       BRA
# 170   Brazil  Americas  1962   55.665    76039390   3336.585802       BRA
# 171   Brazil  Americas  1967   57.632    88049823   3429.864357       BRA
# 172   Brazil  Americas  1972   59.504   100840058   4985.711467       BRA
# 173   Brazil  Americas  1977   61.489   114313951   6660.118654       BRA
# 174   Brazil  Americas  1982   63.336   128962939   7030.835878       BRA
# 175   Brazil  Americas  1987   65.205   142938076   7807.095818       BRA
# 176   Brazil  Americas  1992   67.057   155975974   6950.283021       BRA
# 177   Brazil  Americas  1997   69.388   168546719   7957.980824       BRA
# 178   Brazil  Americas  2002   71.006   179914212   8131.212843       BRA
# 179   Brazil  Americas  2007   72.390   190010647   9065.800825       BRA
# 564  Germany    Europe  1952   67.500    69145952   7144.114393       DEU
# 565  Germany    Europe  1957   69.100    71019069  10187.826650       DEU
# 566  Germany    Europe  1962   70.300    73739117  12902.462910       DEU
# 567  Germany    Europe  1967   70.800    76368453  14745.625610       DEU
# 568  Germany    Europe  1972   71.000    78717088  18016.180270       DEU
# 569  Germany    Europe  1977   72.500    78160773  20512.921230       DEU
# 570  Germany    Europe  1982   73.800    78335266  22031.532740       DEU
# 571  Germany    Europe  1987   74.847    77718298  24639.185660       DEU
# 572  Germany    Europe  1992   76.070    80597764  26505.303170       DEU
# 573  Germany    Europe  1997   77.340    82011073  27788.884160       DEU
# 574  Germany    Europe  2002   78.670    82350671  30035.801980       DEU
# 575  Germany    Europe  2007   79.406    82400996  32170.374420       DEU
# 696    India      Asia  1952   37.373   372000000    546.565749       IND
# 697    India      Asia  1957   40.249   409000000    590.061996       IND
# 698    India      Asia  1962   43.605   454000000    658.347151       IND
# 699    India      Asia  1967   47.193   506000000    700.770611       IND
# 700    India      Asia  1972   50.651   567000000    724.032527       IND
# 701    India      Asia  1977   54.208   634000000    813.337323       IND
# 702    India      Asia  1982   56.596   708000000    855.723538       IND
# 703    India      Asia  1987   58.553   788000000    976.512676       IND
# 704    India      Asia  1992   60.223   872000000   1164.406809       IND
# 705    India      Asia  1997   61.765   959000000   1458.817442       IND
# 706    India      Asia  2002   62.879  1034172547   1746.769454       IND
# 707    India      Asia  2007   64.698  1110396331   2452.210407       IND
#
#      iso_num
# 168       76
# 169       76
# 170       76
# 171       76
# 172       76
# 173       76
# 174       76
# 175       76
# 176       76
# 177       76
# 178       76
# 179       76
# 564      276
# 565      276
# 566      276
# 567      276
# 568      276
# 569      276
# 570      276
# 571      276
# 572      276
# 573      276
# 574      276
# 575      276
# 696      356
# 697      356
# 698      356
# 699      356
# 700      356
# 701      356
# 702      356
# 703      356
# 704      356
# 705      356
# 706      356
# 707      356

# %%
sns.relplot(kind='line',data=temp_df,x='year',y='lifeExp',hue='country',style='continent')

# %%
# face plot -> work on only figure level fuction i.e relplot
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',row='sex',col='smoker')
# we can plot number of different graph using row and col
# it draw separate graph for each value like it make group

# %%
# col wrap -> used for how many columns we want in row

sns.relplot(data=gap,x='lifeExp',y='gdpPercap',kind='scatter',col='year',col_wrap=3)

# %% [markdown]
# # 2. Distribution Plots
# used for univariate analysis
# used to find out the distribution
# Range of the observation
# Central Tendency
# is the data bimodal?
# Are there outliers?
# Plots under distribution plot
#
# histplot
# kdeplot
# rugplot

# %%
# figure level -> displot
# axes level -> histplot -> kdeplot -> rugplot

# %%
# plotting univariate histogram
sns.histplot(data=tips, x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# figure level
sns.displot(data=tips, x='total_bill',kind='hist')

# %%
# bins parameter
sns.displot(data=tips, x='total_bill',kind='hist',bins=20)
# bins divide data in 20 parts

# %%
# It’s also possible to visualize the distribution of a categorical variable using the logic of a histogram. 
# Discrete bins are automatically set for categorical variables

# countplot
sns.displot(data=tips, x='day', kind='hist')

# %%
# hue parameter
sns.displot(data=tips, x='tip', kind='hist',hue='sex')

# %%
# element -> step
sns.displot(data=tips, x='tip', kind='hist',hue='sex',element='step')

# %%
# faceting using col and row -> not work on histplot function
sns.displot(data=tips, x='tip', kind='hist',col='sex')

# %% [markdown]
# **kdeplot**

# %%
# kdeplot -> axes level
# Rather than using discrete bins, a KDE plot smooths the observations with a Gaussian kernel, producing a continuous density estimate
sns.kdeplot(data=tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# figure level

sns.displot(data=tips,x='total_bill',kind='kde')

# %%
# hue -> fill
sns.displot(data=tips,x='total_bill',kind='kde',hue='sex',fill=True)

# %%
# Rugplot

# Plot marginal distributions by drawing ticks along the x and y axes.

# This function is intended to complement other plots by showing the location of individual observations in an unobtrusive way.
sns.kdeplot(data=tips,x='total_bill')
sns.rugplot(data=tips,x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# Bivariate histogram
# A bivariate histogram bins the data within rectangles that tile the plot 
# and then shows the count of observations within each rectangle with the fill color

# sns.histplot(data=tips, x='total_bill', y='tip') #Axes level
sns.displot(data=tips, x='total_bill', y='tip',kind='hist')

# %%
# Bivariate Kdeplot
# a bivariate KDE plot smoothes the (x, y) observations with a 2D Gaussian
sns.kdeplot(data=tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # 3 Matrix Plot
# heatmap
# clustermap

# %%
# heat map  
temp = gap.pivot(index='country',columns='year',values='lifeExp') # pivot convert in table format 
# the main difference between pivot and pivot_table is pivot table doesnot allow repitation

# %%
temp
# Out:
# year                  1952    1957    1962    1967    1972    1977    1982  \
# country
# Afghanistan         28.801  30.332  31.997  34.020  36.088  38.438  39.854
# Albania             55.230  59.280  64.820  66.220  67.690  68.930  70.420
# Algeria             43.077  45.685  48.303  51.407  54.518  58.014  61.368
# Angola              30.015  31.999  34.000  35.985  37.928  39.483  39.942
# Argentina           62.485  64.399  65.142  65.634  67.065  68.481  69.942
# ...                    ...     ...     ...     ...     ...     ...     ...
# Vietnam             40.412  42.887  45.363  47.838  50.254  55.764  58.816
# West Bank and Gaza  43.160  45.671  48.127  51.631  56.532  60.765  64.406
# Yemen, Rep.         32.548  33.970  35.180  36.984  39.848  44.175  49.113
# Zambia              42.038  44.077  46.023  47.768  50.107  51.386  51.821
# Zimbabwe            48.451  50.469  52.358  53.995  55.635  57.674  60.363
#
# year                  1987    1992    1997    2002    2007
# country
# Afghanistan         40.822  41.674  41.763  42.129  43.828
# Albania             72.000  71.581  72.950  75.651  76.423
# Algeria             65.799  67.744  69.152  70.994  72.301
# Angola              39.906  40.647  40.963  41.003  42.731
# Argentina           70.774  71.868  73.275  74.340  75.320
# ...                    ...     ...     ...     ...     ...
# Vietnam             62.820  67.662  70.672  73.017  74.249
# West Bank and Gaza  67.046  69.718  71.096  72.370  73.422
# Yemen, Rep.         52.922  55.599  58.020  60.308  62.698
# Zambia              50.821  46.100  40.238  39.193  42.384
# Zimbabwe            62.351  60.377  46.809  39.989  43.487
#
# [142 rows x 12 columns]

# %%
plt.figure(figsize=(15,15))
sns.heatmap(temp)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
# annot , linewidth , cmap
plt.figure(figsize=(15,15))
temp = gap[gap['continent'] == 'Europe']
temp1 = temp.pivot(index='country',columns='year',values='lifeExp')
sns.heatmap(temp1,annot=True,linewidth=0.5,cmap='viridis') # by annot it shows the number 
# line width create gap between block
# cmap for color
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
# Clustermap

# Plot a matrix dataset as a hierarchically-clustered heatmap.

# This function requires scipy to be available.

iris = px.data.iris()
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# 145           3
# 146           3
# 147           3
# 148           3
# 149           3
#
# [150 rows x 6 columns]

# %%
sns.clustermap(iris.iloc[:,[0,1,2,3]]) # first for row and second for column

# %% [markdown]
# # 4 Categorical Plots
# **Categorical Scatter Plot**
# Stripplot
# Swarmplot
# **Categorical Distribution Plots**
# Boxplot
# Violinplot
# **Categorical Estimate Plot -> for central tendency**
# Barplot
# Pointplot
# Countplot
# Figure level function -> catplot

# %% [markdown]
# **Categorical Scatter Plot**

# %%
# strip plot -> take input one categorical coulmn and one numerical column 
sns.stripplot(data=tips,y='total_bill',x='day')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# figure level function 
sns.catplot(data=tips,x='day',y='total_bill',kind='strip')

# %%
# jitter -> used for seprate distance between points 
sns.catplot(data=tips,x='day',y='total_bill',kind='strip',jitter=0.2,hue='sex')

# %%
# swarmplot -> used for better presentation -> for small dataset -> figure level
#.catplot(data=tips,x='day',y='total_bill',kind="swarm",hue='sex')
sns.swarmplot(data=tips,x='day',y='total_bill',hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# **Categorical Distribution Plots**

# %% [markdown]
# Boxplot
# A boxplot is a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile [Q1], median, third quartile [Q3] and “maximum”). It can tell you about your outliers and what their values are. Boxplots can also tell you if your data is symmetrical, how tightly your data is grouped and if and how your data is skewed.
#
# ![image.png](attachment:e5eeb5c7-be54-4687-87b1-de72ce635e91.png)

# %%
# Box plot
sns.boxplot(data=tips,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# using catplot 
# Box plot
sns.catplot(data=tips,x='day',y='total_bill',kind='box',hue='sex')

# %%
# only numerical col
# Box plot
sns.boxplot(data=tips,y='total_bill')
# Out:
# <Axes: ylabel='total_bill'>

# %% [markdown]
# **violin  plot (box plot + KDE plot )**

# %%
sns.violinplot(data=tips,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# using catplot 
sns.catplot(data=tips,x='day',y='total_bill',kind='violin',hue='sex')

# %% [markdown]
# **bar plot**
# When there are multiple observations in each category, it also uses bootstrapping to compute a confidence interval around the estimate, which is plotted using error bars

# %%
# barplot
# some issue with errorbar
 
sns.barplot(data=tips, x='sex', y='total_bill',hue='smoker',estimator=np.min)
# estimator work here as which opertion we want to perfrom on total bill like mean , median , etc
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# using catplot 
sns.catplot(data=tips, x='sex', y='total_bill',hue='smoker',estimator=np.min,kind='bar',errorbar=None)
# error bar remove the above kine of bar

# %%
# point plot
sns.pointplot(data=tips, x='sex', y='total_bill',hue='smoker',errorbar=None)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# **count plot**
# A special case for the bar plot is when you want to show the number of observations in each category rather than computing a statistic for a second variable. This is similar to a histogram over a categorical, rather than quantitative, variable

# %%
sns.countplot(data=tips,x='sex',hue='day')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# facinating using catplot 
sns.catplot(data=tips,x='sex',y='total_bill',col='smoker',kind='bar',errorbar=None)

# %% [markdown]
# **Regression Plots**
# regplot
# lmplot
# In the simplest invocation, both functions draw a scatterplot of two variables, x and y, and then fit the regression model y ~ x and plot the resulting regression line and a 95% confidence interval for that regression.

# %%
# axis level function 
sns.regplot(data=tips,x='total_bill',y='tip')
# we can can not hue parameter here
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# figure level function 
sns.lmplot(data=tips,x='total_bill',y='tip',hue='sex')

# %%
# residplot 
sns.residplot(data=tips,x='total_bill',y='tip')
# it show our model wrong predication above line or below line
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# **A second way to plot Facet plots -> FacetGrid** )

# %%
g = sns.FacetGrid(data=tips,col='day',row='time',hue='smoker')
g.map(sns.scatterplot,'tip','total_bill')
# tip is x-axis and total_bill is y axis and first part for plot graph

# %% [markdown]
# **Plotting Pairwise Relationship (PairGrid Vs Pairplot)**

# %%
# it work as it atumaticaly plot graph between numerical column all possible combination 
iris = sns.load_dataset('iris')
sns.pairplot(iris,hue='species')
# we have to only give data i.e iris

# %%
# pairGrid 
g = sns.PairGrid(iris,hue='species')
g.map(sns.scatterplot)

# %%
# map_diag -> map_offdiag
g = sns.PairGrid(iris,hue='species')
g.map_diag(sns.histplot)
g.map_offdiag(sns.lineplot)

# we have felxibilty to plot any graph

# %%
# map_diag -> map_upper -> map_lower
g = sns.PairGrid(data=iris,hue='species')
g.map_diag(sns.histplot)
g.map_upper(sns.kdeplot)
g.map_lower(sns.scatterplot)

# %%
# vars
g = sns.PairGrid(data=iris,hue='species',vars=['sepal_width','petal_width'])
g.map_diag(sns.histplot)
g.map_upper(sns.kdeplot)
g.map_lower(sns.scatterplot)

# we can control the how many numerical col we want by vars

# %% [markdown]
# **JointGrid Vs Jointplot**

# %%
sns.jointplot(data=tips,x='total_bill',y='tip',kind='scatter',hue='sex')

# %%
g = sns.JointGrid(data=tips,x='total_bill',y='tip')
g.plot(sns.kdeplot,sns.violinplot)
