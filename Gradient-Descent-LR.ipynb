# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('data/placement-lr.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
X_train,X_test,y_train,y_test = train_test_split(df[['cgpa']],df['package'],test_size=0.2,random_state =2)

# %%
# let's create the LR 
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
print("r2_score is ",r2_score(y_test,y_pred))
# Out:
# r2_score is  0.780730147510384

# %%
# now check the coefficient and intercept
print(lr.coef_,lr.intercept_)
# Out:
# [0.55795197] -0.8961119222429144

# %%
# now let's make our own GD calss by formulas

# %%
class YGD:
    def __init__(self, b, m, lr):
        self.b = b
        self.m = m
        self.lr = lr
    def fit(self, X_train, y_train):
        for _ in range(50):
            n = len(X_train)
            # predictions
            y_pred = self.m * X_train + self.b
            # residuals
            error = 1/n * (y_train - y_pred)
            # correct partial derivatives (SUM loss)
            db = -2 * np.sum(error)
            dm = -2 * np.sum(error * X_train)
            # scalar-safe updates
            self.b = self.b - self.lr * db
            self.m = self.m - self.lr * dm

        print("b =", self.b)
        print("m =", self.m)
        
    def predict(self,X_test):
        return self.m * X + self.b

# %%
lr_max = len(X_train) / (2 * np.sum(X_train**2))
print("Safe learning rate <=", lr_max)
# Out:
# Safe learning rate <= cgpa    0.010001
# dtype: float64
# C:\Users\HP\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
mlr = YGD(-10,100,0.010001)

# %%
mlr.fit(X_train.values,y_train.values)
# Out:
# b = 4.183261896853615e+111
# m = 2.99058848854384e+112

# %%
# just fix the learning rate and we will get the output
